# %% [markdown]
# # Explainer Notebook

# %% [markdown]
# ## 1. Motivation

# %% [markdown]
# #### Our dataset is a combination of data from 3 air quality monitoring stations in Dubai (The Views, Dubai Motor City, and Serena) and additional weather data from Meteostat.
# ##### We chose this dataset because people's health is important and Dubai has higher air pollution than the WHO goal of 15 units. We found this topic particularly interesting on a personal level since ...
# #### Our goal for the end user's experience is to help them identify patterns in pollution(PM2.5 & PM10) levels and investigate environmental factors that play a role into this number.

# %% [markdown]
# ## 2. Basic Stats

# %% [markdown]
# #### For the data cleaning and preprocessing we ....
# #### Talk about Dataset stats. Key points/plots from exploratory data analysis.

# %% [markdown]
# ## 3. Data Analysis

# %% [markdown]
# #### Throughout our data analysis we ... and learned ....
# #### Machine learning.

# %% [markdown]
# ## 4. Genre

# %% [markdown]
# #### Tools from Segal and Heer

# %% [markdown]
# ## 5. Visualizations

# %% [markdown]
# #### We have chosen to create visualizations about ....
# #### These visualizations are the right ones to use because ...

# %% [markdown]
# ## 6. Discussion

# %% [markdown]
# ## 7. Contributions
