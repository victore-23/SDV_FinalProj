# %% [markdown]
# # Explainer Notebook

# %% [markdown]
# ## 1. Motivation

# %% [markdown]
# ## 2. Basic Stats

# %% [markdown]
# ## 3. Data Analysis

# %% [markdown]
# ## 4. Genre

# %% [markdown]
# ## 5. Visualizations

# %% [markdown]
# ## 6. Discussion

# %% [markdown]
# ## 7. Contributions
